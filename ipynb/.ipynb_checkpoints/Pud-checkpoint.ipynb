# %%
# %matplotlib inline
# %autosave 0
    
import logging
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.ERROR, datefmt='%I:%M:%S')
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import os
import sys
import numpy as np
import pandas as pd
import sdata
from sdata.metadata import extract_name_unit
from sdata.timestamp import TimeStamp
import uuid
import openpyxl
import matplotlib.pyplot as plt
import datetime
import re
import requests
modulepath = os.getcwd()
# Out:
# Autosave disabled

# %%
filepath = os.path.join(modulepath, "..", "tests", "io", "pud", "ut_flat.txt")
print(os.path.abspath(filepath))
from sdata.iolib.pud import Pud

pud = Pud.from_file(filepath)
print(pud)
print(pud.metadata)
print(pud.df.head())
# Out:
# /home/ingolf.lepenies/projects/sdata/tests/io/pud/ut_flat.txt
# (Data 'UT_FLAT':7672ad7d9b9f58ecb59a8221b762a7a4)
# (Metadata'N.N.':39 ['sdata_version', 'name', 'uuid', 'WERKSTOFF_NORM_NAME', 'WERKSTOFFNUMMER_NORM', 'MATERIALNAME', 'PRUEFUNG', 'PROBENIDENTNUMMER', 'PROBENGEOMETRIE', 'ENTNAHMERICHTUNG', 'VORVERFORMUNG_SOLL <%>', 'VORVERFORMUNG_IST  <%>', 'VORVERFORMUNGSRICHTUNG', 'WAERMEBEHANDLUNG', 'PROBENBREITE_IST <mm>', 'PROBENDICKE_IST <mm>', 'MESSLAENGE_IST <mm>', 'MESSLAENGE_IST_FD <mm>', 'PRUEFTEMPERATUR_SOLL <K>', 'PRUEFGESCHWINDIGKEIT_SOLL  <mm/s>', 'PRUEFGESCHWINDIGKEIT_IST   <mm/s>', 'DEHNRATE_SOLL <1/s>', 'DEHNRATE_IST  <1/s>', 'AUFTRAG', 'PRUEFDATUM  <tt.mm.jjjj>', 'PRUEFER', 'PRUEFSTELLE', 'BEMERKUNG', 'l0', 'width', 'thickness', 'area', 'actual_testing_temperature', 'sample_direction', 'nominal_pre_deformation', 'actual_pre_deformation', 'nominal_strain_rate', 'actual_strain_rate', 'place_of_test'])
# ...

# %%
pud.metadata.df
# Out:
#                                                                 name  \
# key
# sdata_version                                          sdata_version
# name                                                            name
# uuid                                                            uuid
# WERKSTOFF_NORM_NAME                              WERKSTOFF_NORM_NAME
# WERKSTOFFNUMMER_NORM                            WERKSTOFFNUMMER_NORM
# MATERIALNAME                                            MATERIALNAME
# PRUEFUNG                                                    PRUEFUNG
# PROBENIDENTNUMMER                                  PROBENIDENTNUMMER
# PROBENGEOMETRIE                                      PROBENGEOMETRIE
# ENTNAHMERICHTUNG                                    ENTNAHMERICHTUNG
# VORVERFORMUNG_SOLL <%>                        VORVERFORMUNG_SOLL <%>
# VORVERFORMUNG_IST  <%>                        VORVERFORMUNG_IST  <%>
# ...

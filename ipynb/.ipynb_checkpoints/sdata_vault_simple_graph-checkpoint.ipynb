# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %autosave 0
    
import logging
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG, datefmt='%I:%M:%S')

import os
import sys
import numpy as np
import pandas as pd
import sdata
import uuid
import time
from sdata import Data
from sdata.iolib.vault import FileSystemVault
from sdata.iolib.hdf import FlatHDFDataStore
print("sdata v{}".format(sdata.__version__))
from sdata.contrib.simple_graph import database
# Out:
# Autosave disabled
# 10:32:49 DEBUG:Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# sdata v0.17.0

# %%
vaultrootpath = "/tmp/sdatavaultsimpegraph"
import shutil
shutil.rmtree(vaultrootpath)

# %%
vault = FileSystemVault(vaultrootpath)
vault.index.df
# Out:
# 10:32:49 INFO:create/open vault /tmp/sdatavaultsimpegraph
# Empty DataFrame
# Columns: [!sdata_version, !sdata_name, !sdata_uuid, !sdata_class, !sdata_parent, !sdata_project, !sdata_ctime, !sdata_mtime]
# Index: []

# %%
vault
# Out:
# (FileSystemVault:/tmp/sdatavaultsimpegraph)

# %%
data = sdata.Data(name="otto", 
                  uuid=sdata.uuid_from_str("otto"), 
                  table=pd.DataFrame({"a":[1,2,3]}),
                  description="Hallo\nSpencer",
                  project="P1")
data.metadata.add("a", 1)
datac = data.copy()
datac.uuid = '2689e23926874382b10b95e0f1cd90eb'
data2 = sdata.Data(name="karl", 
                   uuid=sdata.uuid_from_str("karl"))
data, datac, data2
# Out:
# ((Data 'otto':21b83703d98e38a7be2e50e38326d0ce),
#  (Data 'otto':2689e23926874382b10b95e0f1cd90eb),
#  (Data 'karl':df26fe1945b93a149ee710e8fa887b2e))

# %%
vault.dump_blob(data)
vault.dump_blob(data2)
vault.dump_blob(datac)
# Out:
# 10:32:49 INFO:dump blob /tmp/sdatavaultsimpegraph/objects/21/ce/
# 10:32:49 INFO:NumExpr defaulting to 8 threads.
# /home/ingolf.lepenies/anaconda3/envs/sfem3/lib/python3.7/site-packages/ipykernel_launcher.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block0_values] [items->Index(['name', 'value', 'dtype', 'unit', 'description', 'label'], dtype='object')]
#
#   """Entry point for launching an IPython kernel.
# 10:32:50 INFO:dump blob /tmp/sdatavaultsimpegraph/objects/df/2e/
# 10:32:50 INFO:dump blob /tmp/sdatavaultsimpegraph/objects/26/eb/
# /home/ingolf.lepenies/anaconda3/envs/sfem3/lib/python3.7/site-packages/ipykernel_launcher.py:3: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# ...

# %%
vault.dump_hdf5_index()
vault.index.df
# Out:
#                                  !sdata_version !sdata_name  \
# 21b83703d98e38a7be2e50e38326d0ce         0.17.0        otto
# df26fe1945b93a149ee710e8fa887b2e         0.17.0        karl
# 2689e23926874382b10b95e0f1cd90eb         0.17.0        otto
#
#                                                        !sdata_uuid  \
# 21b83703d98e38a7be2e50e38326d0ce  21b83703d98e38a7be2e50e38326d0ce
# df26fe1945b93a149ee710e8fa887b2e  df26fe1945b93a149ee710e8fa887b2e
# 2689e23926874382b10b95e0f1cd90eb  2689e23926874382b10b95e0f1cd90eb
#
#                                  !sdata_class  \
# 21b83703d98e38a7be2e50e38326d0ce         Data
# df26fe1945b93a149ee710e8fa887b2e         Data
# 2689e23926874382b10b95e0f1cd90eb         Data
#
#                                                      !sdata_parent  \
# 21b83703d98e38a7be2e50e38326d0ce
# df26fe1945b93a149ee710e8fa887b2e
# 2689e23926874382b10b95e0f1cd90eb  21b83703d98e38a7be2e50e38326d0ce
#
#                                  !sdata_project  \
# ...

# %%
d = {}
for dat in [data, data2, datac]:
    d[dat.uuid] = dat.metadata.to_dict()
d.keys()
# Out:
# dict_keys(['21b83703d98e38a7be2e50e38326d0ce', 'df26fe1945b93a149ee710e8fa887b2e', '2689e23926874382b10b95e0f1cd90eb'])

# %%
vault.index.df.to_dict(orient="index")
# Out:
# {'21b83703d98e38a7be2e50e38326d0ce': {'!sdata_version': '0.17.0',
#   '!sdata_name': 'otto',
#   '!sdata_uuid': '21b83703d98e38a7be2e50e38326d0ce',
#   '!sdata_class': 'Data',
#   '!sdata_parent': '',
#   '!sdata_project': 'P1',
#   '!sdata_ctime': '2021-01-18T10:32:49.875372+00:00',
#   '!sdata_mtime': '2021-01-18T10:32:49.875466+00:00'},
#  'df26fe1945b93a149ee710e8fa887b2e': {'!sdata_version': '0.17.0',
#   '!sdata_name': 'karl',
#   '!sdata_uuid': 'df26fe1945b93a149ee710e8fa887b2e',
#   '!sdata_class': 'Data',
#   '!sdata_parent': '',
#   '!sdata_project': '',
#   '!sdata_ctime': '2021-01-18T10:32:49.876407+00:00',
#   '!sdata_mtime': '2021-01-18T10:32:49.876470+00:00'},
#  '2689e23926874382b10b95e0f1cd90eb': {'!sdata_version': '0.17.0',
#   '!sdata_name': 'otto',
#   '!sdata_uuid': '2689e23926874382b10b95e0f1cd90eb',
#   '!sdata_class': 'Data',
#   '!sdata_parent': '21b83703d98e38a7be2e50e38326d0ce',
#   '!sdata_project': 'P1',
# ...

# %%
for identifier, datadict in vault.index.df.to_dict(orient="index").items():
    print(identifier, datadict)
# Out:
# 21b83703d98e38a7be2e50e38326d0ce {'!sdata_version': '0.17.0', '!sdata_name': 'otto', '!sdata_uuid': '21b83703d98e38a7be2e50e38326d0ce', '!sdata_class': 'Data', '!sdata_parent': '', '!sdata_project': 'P1', '!sdata_ctime': '2021-01-18T10:32:49.875372+00:00', '!sdata_mtime': '2021-01-18T10:32:49.875466+00:00'}
# df26fe1945b93a149ee710e8fa887b2e {'!sdata_version': '0.17.0', '!sdata_name': 'karl', '!sdata_uuid': 'df26fe1945b93a149ee710e8fa887b2e', '!sdata_class': 'Data', '!sdata_parent': '', '!sdata_project': '', '!sdata_ctime': '2021-01-18T10:32:49.876407+00:00', '!sdata_mtime': '2021-01-18T10:32:49.876470+00:00'}
# 2689e23926874382b10b95e0f1cd90eb {'!sdata_version': '0.17.0', '!sdata_name': 'otto', '!sdata_uuid': '2689e23926874382b10b95e0f1cd90eb', '!sdata_class': 'Data', '!sdata_parent': '21b83703d98e38a7be2e50e38326d0ce', '!sdata_project': 'P1', '!sdata_ctime': '2021-01-18T10:32:49.875372+00:00', '!sdata_mtime': '2021-01-18T10:32:49.876100+00:00'}

# %%
db_name = "sdatavaultsimpegraph.sqlite"

# %%
os.remove(db_name)

# %%
from sdata.contrib.simple_graph import database as db
db.initialize(db_name)

# %%
for uuidhex, datadict in vault.index.df.to_dict(orient="index").items():
#    identifier = db.uuidstr2uuidint(uuidhex)
    identifier = uuidhex
    print(uuidhex, identifier)
    db.atomic(db_name, db.add_node(datadict, identifier))
# Out:
# 21b83703d98e38a7be2e50e38326d0ce 21b83703d98e38a7be2e50e38326d0ce
# df26fe1945b93a149ee710e8fa887b2e df26fe1945b93a149ee710e8fa887b2e
# 2689e23926874382b10b95e0f1cd90eb 2689e23926874382b10b95e0f1cd90eb

# %%
db.visualize(db_name, '{}.dot'.format(db_name), ['2689e23926874382b10b95e0f1cd90eb', '21b83703d98e38a7be2e50e38326d0ce', 'df26fe1945b93a149ee710e8fa887b2e'])

os.system("dot -Tpng {0}.dot -o {0}.png".format(db_name))
# Out:
# 0

# %%
#db.atomic(db_name, db.find_node(51226596861945717314284025759969153259))
identifier = '2689e23926874382b10b95e0f1cd90eb'
db.atomic(db_name, db.find_node(identifier))
# Out:
# {'!sdata_version': '0.17.0',
#  '!sdata_name': 'otto',
#  '!sdata_uuid': '2689e23926874382b10b95e0f1cd90eb',
#  '!sdata_class': 'Data',
#  '!sdata_parent': '21b83703d98e38a7be2e50e38326d0ce',
#  '!sdata_project': 'P1',
#  '!sdata_ctime': '2021-01-18T10:32:49.875372+00:00',
#  '!sdata_mtime': '2021-01-18T10:32:49.876100+00:00',
#  'id': '2689e23926874382b10b95e0f1cd90eb'}

# %%
uuidhex = '21b83703d98e38a7be2e50e38326d0ce'
# db.atomic(db_name, db.find_node(db.uuidstr2uuidint(uuidhex)))
db.atomic(db_name, db.find_node(uuidhex))
# Out:
# {'!sdata_version': '0.17.0',
#  '!sdata_name': 'otto',
#  '!sdata_uuid': '21b83703d98e38a7be2e50e38326d0ce',
#  '!sdata_class': 'Data',
#  '!sdata_parent': '',
#  '!sdata_project': 'P1',
#  '!sdata_ctime': '2021-01-18T10:32:49.875372+00:00',
#  '!sdata_mtime': '2021-01-18T10:32:49.875466+00:00',
#  'id': '21b83703d98e38a7be2e50e38326d0ce'}

# %%
db.atomic(db_name, db.find_nodes({'!sdata_name': 'karl'}, db._search_like, db._search_starts_with))
# Out:
# [{'!sdata_version': '0.17.0',
#   '!sdata_name': 'karl',
#   '!sdata_uuid': 'df26fe1945b93a149ee710e8fa887b2e',
#   '!sdata_class': 'Data',
#   '!sdata_parent': '',
#   '!sdata_project': '',
#   '!sdata_ctime': '2021-01-18T10:32:49.876407+00:00',
#   '!sdata_mtime': '2021-01-18T10:32:49.876470+00:00',
#   'id': 'df26fe1945b93a149ee710e8fa887b2e'}]

# %%
db.atomic(db_name, db.find_nodes({'!sdata_name': 'otto'}, db._search_like, db._search_starts_with))
# Out:
# [{'!sdata_version': '0.17.0',
#   '!sdata_name': 'otto',
#   '!sdata_uuid': '21b83703d98e38a7be2e50e38326d0ce',
#   '!sdata_class': 'Data',
#   '!sdata_parent': '',
#   '!sdata_project': 'P1',
#   '!sdata_ctime': '2021-01-18T10:32:49.875372+00:00',
#   '!sdata_mtime': '2021-01-18T10:32:49.875466+00:00',
#   'id': '21b83703d98e38a7be2e50e38326d0ce'},
#  {'!sdata_version': '0.17.0',
#   '!sdata_name': 'otto',
#   '!sdata_uuid': '2689e23926874382b10b95e0f1cd90eb',
#   '!sdata_class': 'Data',
#   '!sdata_parent': '21b83703d98e38a7be2e50e38326d0ce',
#   '!sdata_project': 'P1',
#   '!sdata_ctime': '2021-01-18T10:32:49.875372+00:00',
#   '!sdata_mtime': '2021-01-18T10:32:49.876100+00:00',
#   'id': '2689e23926874382b10b95e0f1cd90eb'}]

# %%
db.atomic(db_name, db.find_nodes({'!sdata_name': ''}, db._search_like, db._search_starts_with))
# Out:
# [{'!sdata_version': '0.17.0',
#   '!sdata_name': 'otto',
#   '!sdata_uuid': '21b83703d98e38a7be2e50e38326d0ce',
#   '!sdata_class': 'Data',
#   '!sdata_parent': '',
#   '!sdata_project': 'P1',
#   '!sdata_ctime': '2021-01-18T10:32:49.875372+00:00',
#   '!sdata_mtime': '2021-01-18T10:32:49.875466+00:00',
#   'id': '21b83703d98e38a7be2e50e38326d0ce'},
#  {'!sdata_version': '0.17.0',
#   '!sdata_name': 'karl',
#   '!sdata_uuid': 'df26fe1945b93a149ee710e8fa887b2e',
#   '!sdata_class': 'Data',
#   '!sdata_parent': '',
#   '!sdata_project': '',
#   '!sdata_ctime': '2021-01-18T10:32:49.876407+00:00',
#   '!sdata_mtime': '2021-01-18T10:32:49.876470+00:00',
#   'id': 'df26fe1945b93a149ee710e8fa887b2e'},
#  {'!sdata_version': '0.17.0',
#   '!sdata_name': 'otto',
#   '!sdata_uuid': '2689e23926874382b10b95e0f1cd90eb',
#   '!sdata_class': 'Data',
#   '!sdata_parent': '21b83703d98e38a7be2e50e38326d0ce',
#   '!sdata_project': 'P1',
#   '!sdata_ctime': '2021-01-18T10:32:49.875372+00:00',
# ...

# %%
for uuidhex, datadict in vault.index.df.to_dict(orient="index").items():
#     identifier = db.uuidstr2uuidint(uuidhex)
    uuidparent = datadict.get('!sdata_parent')
    if uuidparent:
        print(uuidhex, uuidparent)
        identifier = '"{}"'.format(uuidhex)
        parent_identifier = '"{}"'.format(uuidparent)
#         parent_identifier = db.uuidstr2uuidint(parent)
#         print(parent_identifier, identifier)
#        db.atomic(db_name, db.connect_nodes(parent_identifier, identifier, {}))
        db.atomic(db_name, db.connect_nodes(uuidparent, uuidhex, {'action': 'founded'}))
# Out:
# 2689e23926874382b10b95e0f1cd90eb 21b83703d98e38a7be2e50e38326d0ce

# %%
db.traverse(db_name, 1, neighbors_fn=db.find_inbound_neighbors)
# Out:
# []

# %%
import json
json.loads('"21b83703d98e38a7be2e50e38326d0ce"')
# Out:
# '21b83703d98e38a7be2e50e38326d0ce'

# %%
db.traverse(db_name, '2689e23926874382b10b95e0f1cd90eb', neighbors_fn=db.find_inbound_neighbors)
# Out:
# ['2689e23926874382b10b95e0f1cd90eb', '21b83703d98e38a7be2e50e38326d0ce']

# %%
db.traverse(db_name, '21b83703d98e38a7be2e50e38326d0ce', neighbors_fn=db.find_inbound_neighbors)
# Out:
# ['21b83703d98e38a7be2e50e38326d0ce']

# %%
db.traverse(db_name, '21b83703d98e38a7be2e50e38326d0ce', neighbors_fn=db.find_outbound_neighbors)
# Out:
# ['21b83703d98e38a7be2e50e38326d0ce', '2689e23926874382b10b95e0f1cd90eb']

# %%
db.traverse(db_name, '2689e23926874382b10b95e0f1cd90eb', neighbors_fn=db.find_outbound_neighbors)
# Out:
# ['2689e23926874382b10b95e0f1cd90eb']

# %%
db.traverse(db_name, '2689e23926874382b10b95e0f1cd90eb', neighbors_fn=db.find_neighbors)
# Out:
# ['2689e23926874382b10b95e0f1cd90eb', '21b83703d98e38a7be2e50e38326d0ce']

# %%
tmpl = '!sdata_version {!sdata_version}\n!sdata_name {!sdata_name}\n!sdata_uuid {!sdata_uuid}\n!sdata_class {!sdata_class}\n!sdata_parent {!sdata_parent}\n!sdata_project {!sdata_project}\n!sdata_ctime {!sdata_ctime}\n!sdata_mtime {!sdata_mtime}'
print(tmpl)
tmpl
data = {'!sdata_version': '0.17.0', '!sdata_name': 'otto', '!sdata_uuid': '2689e23926874382b10b95e0f1cd90eb', '!sdata_class': 'Data', '!sdata_parent': '21b83703d98e38a7be2e50e38326d0ce', '!sdata_project': 'P1', '!sdata_ctime': '2021-01-18T08:52:45.762295+00:00', '!sdata_mtime': '2021-01-18T08:52:45.763161+00:00', 'id': '2689e23926874382b10b95e0f1cd90eb'}
data
# Out:
# !sdata_version {!sdata_version}
# !sdata_name {!sdata_name}
# !sdata_uuid {!sdata_uuid}
# !sdata_class {!sdata_class}
# !sdata_parent {!sdata_parent}
# !sdata_project {!sdata_project}
# !sdata_ctime {!sdata_ctime}
# !sdata_mtime {!sdata_mtime}
# {'!sdata_version': '0.17.0',
#  '!sdata_name': 'otto',
#  '!sdata_uuid': '2689e23926874382b10b95e0f1cd90eb',
#  '!sdata_class': 'Data',
#  '!sdata_parent': '21b83703d98e38a7be2e50e38326d0ce',
#  '!sdata_project': 'P1',
#  '!sdata_ctime': '2021-01-18T08:52:45.762295+00:00',
#  '!sdata_mtime': '2021-01-18T08:52:45.763161+00:00',
#  'id': '2689e23926874382b10b95e0f1cd90eb'}

# %%
db.visualize(db_name, '{}.dot'.format(db_name), ['2689e23926874382b10b95e0f1cd90eb', '21b83703d98e38a7be2e50e38326d0ce', 'df26fe1945b93a149ee710e8fa887b2e'])

os.system("dot -Tpng {0}.dot -o {0}.png".format(db_name))
# Out:
# !!node {'!sdata_version': '0.17.0', '!sdata_name': 'otto', '!sdata_uuid': '2689e23926874382b10b95e0f1cd90eb', '!sdata_class': 'Data', '!sdata_parent': '21b83703d98e38a7be2e50e38326d0ce', '!sdata_project': 'P1', '!sdata_ctime': '2021-01-18T10:32:49.875372+00:00', '!sdata_mtime': '2021-01-18T10:32:49.876100+00:00', 'id': '2689e23926874382b10b95e0f1cd90eb'}
# !!node {'!sdata_version': '0.17.0', '!sdata_name': 'otto', '!sdata_uuid': '21b83703d98e38a7be2e50e38326d0ce', '!sdata_class': 'Data', '!sdata_parent': '', '!sdata_project': 'P1', '!sdata_ctime': '2021-01-18T10:32:49.875372+00:00', '!sdata_mtime': '2021-01-18T10:32:49.875466+00:00', 'id': '21b83703d98e38a7be2e50e38326d0ce'}
# ...

# %%
pwd
# Out:
# '/home/ingolf.lepenies/projects/sdata/ipynb'

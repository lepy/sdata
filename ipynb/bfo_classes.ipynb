# %%
#setup notebook
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import logging
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG, datefmt='%I:%M:%S')

import sdata
import sdata.base
import sdata.sclass as api
import sdata.sclass.bfo_classes as bfo
# Out:
# 10:51:19 DEBUG:Loaded backend inline version unknown.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bfo.Function()
# Out:
# <bfo:Function>

# %% [markdown]
# ![image.png](attachment:44ff5654-4bf4-4587-af75-b3914bbd4cee.png)

# %%
"""
digraph "bfo_classes.py" {

splines  = ortho;
fontname = "Inconsolata";

node [colorscheme = ylgnbu4];
edge [colorscheme = dark28, dir = both];

object                                                     [shape = record, pos = "4.139,13.917!"    , label = "{ object |  }"];
"sdata.sclass.bfo_classes.Continuant"                      [shape = record, pos = "0.299,9.750!"     , label = "{ sdata.sclass.bfo_classes.Continuant |  }"];
"sdata.sclass.bfo_classes.ContinuantFiatBoundary"          [shape = record, pos = "22.917,3.083!"    , label = "{ sdata.sclass.bfo_classes.ContinuantFiatBoundary |  }"];
"sdata.sclass.bfo_classes.Disposition"                     [shape = record, pos = "1.118,3.083!"     , label = "{ sdata.sclass.bfo_classes.Disposition |  }"];
"sdata.sclass.bfo_classes.Entity"                          [shape = record, pos = "2.806,12.250!"    , label = "{ sdata.sclass.bfo_classes.Entity |  }"];
"sdata.sclass.bfo_classes.FiatLine"                        [shape = record, pos = "16.306,1.417!"    , label = "{ sdata.sclass.bfo_classes.FiatLine |  }"];
"sdata.sclass.bfo_classes.FiatObjectPart"                  [shape = record, pos = "15.132,3.917!"    , label = "{ sdata.sclass.bfo_classes.FiatObjectPart |  }"];
"sdata.sclass.bfo_classes.FiatPoint"                       [shape = record, pos = "13.750,0.583!"    , label = "{ sdata.sclass.bfo_classes.FiatPoint |  }"];
"sdata.sclass.bfo_classes.FiatSurface"                     [shape = record, pos = "11.125,1.417!"    , label = "{ sdata.sclass.bfo_classes.FiatSurface |  }"];
"sdata.sclass.bfo_classes.Function"                        [shape = record, pos = "-1.243,0.583!"    , label = "{ sdata.sclass.bfo_classes.Function |  }"];
"sdata.sclass.bfo_classes.GenericallyDependentContinuant"  [shape = record, pos = "-3.382,7.250!"    , label = "{ sdata.sclass.bfo_classes.GenericallyDependentContinuant |  }"];
"sdata.sclass.bfo_classes.History"                         [shape = record, pos = "32.174,5.583!"    , label = "{ sdata.sclass.bfo_classes.History |  }"];
"sdata.sclass.bfo_classes.ImmaterialEntity"                [shape = record, pos = "26.701,5.583!"    , label = "{ sdata.sclass.bfo_classes.ImmaterialEntity |  }"];
"sdata.sclass.bfo_classes.IndependentContinuant"           [shape = record, pos = "14.069,8.083!"    , label = "{ sdata.sclass.bfo_classes.IndependentContinuant |  }"];
"sdata.sclass.bfo_classes.MaterialEntity"                  [shape = record, pos = "21.271,5.583!"    , label = "{ sdata.sclass.bfo_classes.MaterialEntity |  }"];
"sdata.sclass.bfo_classes.Object"                          [shape = record, pos = "18.326,3.083!"    , label = "{ sdata.sclass.bfo_classes.Object |  }"];
"sdata.sclass.bfo_classes.ObjectAggregate"                 [shape = record, pos = "12.215,3.083!"    , label = "{ sdata.sclass.bfo_classes.ObjectAggregate |  }"];
"sdata.sclass.bfo_classes.Occurrent"                       [shape = record, pos = "2.868,10.583!"    , label = "{ sdata.sclass.bfo_classes.Occurrent |  }"];
"sdata.sclass.bfo_classes.OneDimensionalSpatialRegion"     [shape = record, pos = "18.736,0.583!"    , label = "{ sdata.sclass.bfo_classes.OneDimensionalSpatialRegion |  }"];
"sdata.sclass.bfo_classes.OneDimensionalTemporalRegion"    [shape = record, pos = "6.653,5.583!"     , label = "{ sdata.sclass.bfo_classes.OneDimensionalTemporalRegion |  }"];
"sdata.sclass.bfo_classes.Process"                         [shape = record, pos = "25.743,8.083!"    , label = "{ sdata.sclass.bfo_classes.Process |  }"];
"sdata.sclass.bfo_classes.ProcessBoundary"                 [shape = record, pos = "22.451,7.250!"    , label = "{ sdata.sclass.bfo_classes.ProcessBoundary |  }"];
"sdata.sclass.bfo_classes.Quality"                         [shape = record, pos = "2.194,5.583!"     , label = "{ sdata.sclass.bfo_classes.Quality |  }"];
"sdata.sclass.bfo_classes.RealizableEntity"                [shape = record, pos = "-3.285,5.583!"    , label = "{ sdata.sclass.bfo_classes.RealizableEntity |  }"];
"sdata.sclass.bfo_classes.RelationalQuality"               [shape = record, pos = "3.896,3.917!"     , label = "{ sdata.sclass.bfo_classes.RelationalQuality |  }"];
"sdata.sclass.bfo_classes.Role"                            [shape = record, pos = "-3.222,3.083!"    , label = "{ sdata.sclass.bfo_classes.Role |  }"];
"sdata.sclass.bfo_classes.Site"                            [shape = record, pos = "32.361,3.083!"    , label = "{ sdata.sclass.bfo_classes.Site |  }"];
"sdata.sclass.bfo_classes.SpatialRegion"                   [shape = record, pos = "26.833,3.917!"    , label = "{ sdata.sclass.bfo_classes.SpatialRegion |  }"];
"sdata.sclass.bfo_classes.SpatiotemporalRegion"            [shape = record, pos = "30.549,7.250!"    , label = "{ sdata.sclass.bfo_classes.SpatiotemporalRegion |  }"];
"sdata.sclass.bfo_classes.SpecificallyDependentContinuant" [shape = record, pos = "3.826,7.250!"     , label = "{ sdata.sclass.bfo_classes.SpecificallyDependentContinuant |  }"];
"sdata.sclass.bfo_classes.TemporalInstant"                 [shape = record, pos = "9.465,3.917!"     , label = "{ sdata.sclass.bfo_classes.TemporalInstant |  }"];
"sdata.sclass.bfo_classes.TemporalInterval"                [shape = record, pos = "6.667,3.083!"     , label = "{ sdata.sclass.bfo_classes.TemporalInterval |  }"];
"sdata.sclass.bfo_classes.TemporalRegion"                  [shape = record, pos = "11.139,7.250!"    , label = "{ sdata.sclass.bfo_classes.TemporalRegion |  }"];
"sdata.sclass.bfo_classes.ThreeDimensionalSpatialRegion"   [shape = record, pos = "22.257,1.417!"    , label = "{ sdata.sclass.bfo_classes.ThreeDimensionalSpatialRegion |  }"];
"sdata.sclass.bfo_classes.TwoDimensionalSpatialRegion"     [shape = record, pos = "29.556,1.417!"    , label = "{ sdata.sclass.bfo_classes.TwoDimensionalSpatialRegion |  }"];
"sdata.sclass.bfo_classes.ZeroDimensionalSpatialRegion"    [shape = record, pos = "25.931,0.583!"    , label = "{ sdata.sclass.bfo_classes.ZeroDimensionalSpatialRegion |  }"];
"sdata.sclass.bfo_classes.ZeroDimensionalTemporalRegion"   [shape = record, pos = "13.847,5.583!"    , label = "{ sdata.sclass.bfo_classes.ZeroDimensionalTemporalRegion |  }"];
"typing.Hashable"                                          [shape = record, pos = "3.604,15.583!"    , label = "{ typing.Hashable |  }"];

object                                                     -> "typing.Hashable"                                          [color = "#595959", style = dashed, arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.Continuant"                      -> "sdata.sclass.bfo_classes.Entity"                          [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.ContinuantFiatBoundary"          -> "sdata.sclass.bfo_classes.ImmaterialEntity"                [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.Disposition"                     -> "sdata.sclass.bfo_classes.RealizableEntity"                [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.Entity"                          -> object                                                     [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.FiatLine"                        -> "sdata.sclass.bfo_classes.ContinuantFiatBoundary"          [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.FiatObjectPart"                  -> "sdata.sclass.bfo_classes.MaterialEntity"                  [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.FiatPoint"                       -> "sdata.sclass.bfo_classes.ContinuantFiatBoundary"          [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.FiatSurface"                     -> "sdata.sclass.bfo_classes.ContinuantFiatBoundary"          [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.Function"                        -> "sdata.sclass.bfo_classes.Disposition"                     [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.GenericallyDependentContinuant"  -> "sdata.sclass.bfo_classes.Continuant"                      [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.History"                         -> "sdata.sclass.bfo_classes.Process"                         [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.ImmaterialEntity"                -> "sdata.sclass.bfo_classes.IndependentContinuant"           [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.IndependentContinuant"           -> "sdata.sclass.bfo_classes.Continuant"                      [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.MaterialEntity"                  -> "sdata.sclass.bfo_classes.IndependentContinuant"           [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.Object"                          -> "sdata.sclass.bfo_classes.MaterialEntity"                  [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.ObjectAggregate"                 -> "sdata.sclass.bfo_classes.MaterialEntity"                  [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.Occurrent"                       -> "sdata.sclass.bfo_classes.Entity"                          [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.OneDimensionalSpatialRegion"     -> "sdata.sclass.bfo_classes.SpatialRegion"                   [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.OneDimensionalTemporalRegion"    -> "sdata.sclass.bfo_classes.TemporalRegion"                  [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.Process"                         -> "sdata.sclass.bfo_classes.Occurrent"                       [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.ProcessBoundary"                 -> "sdata.sclass.bfo_classes.Occurrent"                       [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.Quality"                         -> "sdata.sclass.bfo_classes.SpecificallyDependentContinuant" [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.RealizableEntity"                -> "sdata.sclass.bfo_classes.SpecificallyDependentContinuant" [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.RelationalQuality"               -> "sdata.sclass.bfo_classes.Quality"                         [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.Role"                            -> "sdata.sclass.bfo_classes.RealizableEntity"                [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.Site"                            -> "sdata.sclass.bfo_classes.ImmaterialEntity"                [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.SpatialRegion"                   -> "sdata.sclass.bfo_classes.ImmaterialEntity"                [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.SpatiotemporalRegion"            -> "sdata.sclass.bfo_classes.Occurrent"                       [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.SpecificallyDependentContinuant" -> "sdata.sclass.bfo_classes.Continuant"                      [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.TemporalInstant"                 -> "sdata.sclass.bfo_classes.ZeroDimensionalTemporalRegion"   [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.TemporalInterval"                -> "sdata.sclass.bfo_classes.OneDimensionalTemporalRegion"    [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.TemporalRegion"                  -> "sdata.sclass.bfo_classes.Occurrent"                       [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.ThreeDimensionalSpatialRegion"   -> "sdata.sclass.bfo_classes.SpatialRegion"                   [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.TwoDimensionalSpatialRegion"     -> "sdata.sclass.bfo_classes.SpatialRegion"                   [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.ZeroDimensionalSpatialRegion"    -> "sdata.sclass.bfo_classes.SpatialRegion"                   [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];
"sdata.sclass.bfo_classes.ZeroDimensionalTemporalRegion"   -> "sdata.sclass.bfo_classes.TemporalRegion"                  [color = "#595959", style = solid , arrowtail = normal  , arrowhead = none    , taillabel = "", label = "", headlabel = ""];

}
"""
# Out:
#   Cell In[1], line 1
#     ```
#     ^
# SyntaxError: invalid syntax

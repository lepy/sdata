# %% [markdown]
# # sdata.Attribute

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#%matplotlib notebook
# %autosave 0
    
import logging
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG, datefmt='%I:%M:%S')

import os
import sys
import numpy as np
import pandas as pd
import sdata
# Out:
# 03:02:45 INFO:Note: NumExpr detected 22 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# 03:02:45 INFO:NumExpr defaulting to 16 threads.
# Autosave disabled

# %%
m = sdata.Metadata(name="My first metadata")
m
# Out:
# (Metadata'My first metadata':0)

# %%
#help(m)

# %% [markdown]
# # sdata.Attribute

# %% [markdown]
# create a simple key-value-Attribute

# %%
value = 1
print(sdata.Attribute.guess_dtype(value))
a = sdata.Attribute("otto1", value, dtype=int, ontology="BFO0815")
a.to_dict()
# Out:
# <class 'int'>
# {'name': 'otto1',
#  'value': 1,
#  'unit': '-',
#  'dtype': 'int',
#  'description': '',
#  'label': '',
#  'required': False,
#  'ontology': 'BFO0815'}

# %%
value = [1, "a"]
print(sdata.Attribute.guess_dtype(value))
b = sdata.Attribute("ls", value, dtype=list, ontology="BFO0816")
b.to_dict()
# Out:
# list[str]
# {'name': 'ls',
#  'value': ['1', 'a'],
#  'unit': '-',
#  'dtype': 'list',
#  'description': '',
#  'label': '',
#  'required': False,
#  'ontology': 'BFO0816'}

# %% [markdown]
# create a full qualified Attribute

# %%
value = [1, "c"]
print(sdata.Attribute.guess_dtype(value))
b = sdata.Attribute("ls", value, dtype="list")
b.to_dict()
# Out:
# list[str]
# {'name': 'ls',
#  'value': ['1', 'c'],
#  'unit': '-',
#  'dtype': 'list',
#  'description': '',
#  'label': '',
#  'required': False,
#  'ontology': ''}

# %%
fx = sdata.Attribute("force_x", value=1.2, unit="kN", dtype="float", description="force in x-direction")
fx
# Out:
# (Attr'force_x':1.2(float))

# %% [markdown]
# add Attribute to metadata

# %%
fx.dtype
# Out:
# 'float'

# %%
m = sdata.Metadata(name="m1")
m.add(fx)
m.add(a)
m.add(b)
m.attributes
# Out:
# SortedDict({'force_x': (Attr'force_x':1.2(float)), 'ls': (Attr'ls':['1', 'c'](list)), 'otto1': (Attr'otto1':1(int))})

# %%
m.add("Fy", value=3.1, unit="N", dtype="float", description="force in y-direction", prefix="Load/")
m.attributes
# Out:
# SortedDict({'Load/Fy': (Attr'Fy':3.1(float)), 'force_x': (Attr'force_x':1.2(float)), 'ls': (Attr'ls':['1', 'c'](list)), 'otto1': (Attr'otto1':1(int))})

# %%
m.df
# Out:
#             name   value unit  dtype           description label  required  \
# key
# Fy            Fy     3.1    N  float  force in y-direction           False
# force_x  force_x     1.2   kN  float  force in x-direction           False
# ls            ls  [1, c]    -   list                                 False
# otto1      otto1       1    -    int                                 False
#
#         ontology
# key
# Fy
# force_x
# ls
# otto1    BFO0815

# %%
sdata.Metadata.from_json(m.to_json()).df
# Out:
#             name   value unit  dtype           description label  required  \
# key
# Fy            Fy     3.1    N  float  force in y-direction           False
# force_x  force_x     1.2   kN  float  force in x-direction           False
# ls            ls  [1, c]    -   list                                 False
# otto1      otto1       1    -    int                                 False
#
#         ontology
# key
# Fy
# force_x
# ls
# otto1    BFO0815

# %%
m.keys()
# Out:
# ['Load/Fy', 'force_x', 'ls', 'otto1']

# %%
m.get('Load/Fy')
# Out:
# (Attr'Fy':3.1(float))

# %%
m.get('Fy')
# Out:
# (Attr'Fy':None(str))

# %%
m["otto1"].to_dict()
# Out:
# {'name': 'otto1',
#  'value': 1,
#  'unit': '-',
#  'dtype': 'int',
#  'description': '',
#  'label': '',
#  'required': False,
#  'ontology': 'BFO0815'}

# %%
m.df
# Out:
#             name   value unit  dtype           description label  required  \
# key
# Fy            Fy     3.1    N  float  force in y-direction           False
# force_x  force_x     1.2   kN  float  force in x-direction           False
# ls            ls  [1, c]    -   list                                 False
# otto1      otto1       1    -    int                                 False
#
#         ontology
# key
# Fy
# force_x
# ls
# otto1    BFO0815

# %%
mdict = m.to_dict()
mdict
# Out:
# {'force_x': {'name': 'force_x',
#   'value': 1.2,
#   'unit': 'kN',
#   'dtype': 'float',
#   'description': 'force in x-direction',
#   'label': '',
#   'required': False,
#   'ontology': ''},
#  'ls': {'name': 'ls',
#   'value': ['1', 'c'],
#   'unit': '-',
#   'dtype': 'list',
#   'description': '',
#   'label': '',
#   'required': False,
#   'ontology': ''},
#  'otto1': {'name': 'otto1',
#   'value': 1,
#   'unit': '-',
#   'dtype': 'int',
#   'description': '',
#   'label': '',
#   'required': False,
#   'ontology': 'BFO0815'}}

# %%
sdata.Metadata.from_dict(mdict).df
# Out:
#             name   value unit  dtype           description label  required  \
# key
# force_x  force_x     1.2   kN  float  force in x-direction           False
# ls            ls  [1, c]    -   list                                 False
# otto1      otto1       1    -    int                                 False
#
#         ontology
# key
# force_x
# ls
# otto1    BFO0815

# %%
b
# Out:
# (Attr'ls':['1', 'c'](list))

# %% [markdown]
# ## Working with Attributes

# %%
m["a"] = 1

# %%
m["a"] = 1
m["b"] = 2.1
m["o"] = "c"
m.df

# %%
for a in m:
    print(a)

# %%
[a.value for k, a in m]

# %%
m["b"].value

# %%
m.pop("a")

# %%
"a" in m

# %%
m.get("a")

# %%
m["a"] = a
m.df

# %%
m["force_y"]

# %%
m["force_x"]

# %%
m.get("force_z") # not available -> None

# %%
my_fx = m.get("force_x")
my_fx

# %%
my_fy = m.get("force_y")
my_fy

# %%
my_fx.value

# %%
print("The {0.name} is {0.value} {0.unit}.".format(my_fx))
print("The {0.name} is {0.value} {0.unit}.".format(my_fy))

# %%
my_fx.to_list()

# %%
my_fx.to_dict()

# %%
my_fx.to_csv(prefix="#$", sep=";")

# %% [markdown]
# ## working with Metadata

# %%
m.keys()

# %%
m.values()

# %%
m.items()

# %%
m.to_dict()

# %%
m.to_dict()

# %%
m.to_dataframe()

# %% [markdown]
# ### json IO

# %%
print(m.to_csv(filepath=None))

# %%
print(m.to_csv_header(prefix="##", sep="\t"))

# %%
jsonfilepath = "/tmp/m.json"
print(m.to_json(filepath=jsonfilepath))

# %%
json_str = """{"force_x": {"name": "force_x", "value": 1.2, "unit": "kN", "dtype": "float", "description": "force in x-direction"}, "force_y": {"name": "force_y", "value": 3.1, "unit": "N", "dtype": "float", "description": "force in y-direction"}}"""
m_json = sdata.Metadata.from_json(json_str)
m_json.df

# %%
m_jsonfile = sdata.Metadata.from_json(filepath=jsonfilepath)
m_jsonfile.df

# %% [markdown]
# ### list IO

# %%
m.to_list()

# %%
m2 = sdata.Metadata.from_list([['force_x', 1.2, 'float', 'kN', 'force in x-direction'],
 ['force_y', 3.1, 'float', 'N', 'force in y-direction'],["a",2], ["2"]])
m2.df

# %%
m.df.loc["force_x", "value"]

# %%
m.df.loc[:, "value"]

# %%
c=sdata.Attribute("a_bool", True, dtype="bool", description="a boolean")
c.to_list()

# %%
m = sdata.Metadata.from_dict({"a":"1", "b":1.1})
m.df

# %%
m.to_dict()

# %%
import datetime
datetime.datetime.now().strftime("%d.%m.%Y")

# %%
l = m.to_list()
m.from_list(l)

# %%
m.to_list()

# %%
m.df.values.tolist()

# %%
pd.DataFrame.from_records(m.df.values.tolist())

# %%
df = pd.DataFrame.from_records(m.df.values.tolist(), columns=m.df.columns)
df

# %%
df.to_clipboard()

# %%
pd.read_clipboard()

# %%
for x in [['force_x', 1.2, 'float', 'kN', 'force in x-direction'],
 ['force_y', 3.1, 'float', 'N', 'force in y-direction']]:
    print(x)

# %%
m.to_dict()

# %%
md = m.from_dict({'force_x': {'name': 'force_x',
  'value': 1.2,
  'unit': 'kN',
  'dtype': 'float',
  'description': 'force in x-direction'},
 'force_y': {'name': 'force_y',
  'value': 3.1,
  'description': 'force in y-direction'},
  'force_y': {'name': 'force_z',
  'value': 3.1,
  'description': 'force in y-direction'}})
md.df

# %%
m = sdata.Metadata.from_list([["a",2], 
                              ["!sdata_name", "hallo"], 
                              ["Temperature T [degC]", 23, "°C", "float"],
                              ["force F [kN]", 1.23, "kN"]
                             ])
m.df

# %%
m.set_unit_from_name()
m.df

# %%
m.attributes

# %%
m.user_attributes

# %%
m.sdata_attributes

# %%
m = sdata.Metadata.from_list([["a",2], 
                              ["!sdata_name", "hallo"], 
                              ["Temperature T [degC]", "23", "str"],
                              ["force F [kN]", "1.23", "str"]
                             ])
m.df

# %%
m.guess_value_dtype()
m.df

# %%
m.to_dict()

# %%
filepath = "/tmp/metadata.csv"
m.add("foo", 123)
m.to_csv(filepath)
m5 = sdata.metadata.Metadata.from_csv(filepath)
print("m5", m5.to_dict())
assert m.get_attr("foo").name==m5.get_attr("foo").name
assert m.get_attr("foo").value==m5.get_attr("foo").value

# %%
m.sha3_256, m5.sha3_256

# %%
m5.df

# %%
m.df

# %%
df = m5.df
df.fillna("", inplace=True)
df.replace("nan", "", inplace=True)
df

# %%
m5.df.description.values[0]

# %%
m.to_dict()
# Out:
# {'Fy': {'name': 'Fy',
#   'value': 3.1,
#   'unit': 'N',
#   'dtype': 'float',
#   'description': 'force in y-direction',
#   'label': '',
#   'required': False,
#   'ontology': ''},
#  'force_x': {'name': 'force_x',
#   'value': 1.2,
#   'unit': 'kN',
#   'dtype': 'float',
#   'description': 'force in x-direction',
#   'label': '',
#   'required': False,
#   'ontology': ''},
#  'ls': {'name': 'ls',
#   'value': ['1', 'c'],
#   'unit': '-',
#   'dtype': 'list',
#   'description': '',
#   'label': '',
#   'required': False,
#   'ontology': ''},
#  'otto1': {'name': 'otto1',
#   'value': 1,
#   'unit': '-',
#   'dtype': 'int',
#   'description': '',
#   'label': '',
#   'required': False,
#   'ontology': 'BFO0815'}}

# %%
m.user_attributes
# Out:
# SortedDict({'Fy': (Attr'Fy':3.1(float)), 'force_x': (Attr'force_x':1.2(float)), 'ls': (Attr'ls':['1', 'c'](list)), 'otto1': (Attr'otto1':1(int))})

# %%
sdata.SUUID(class_name="Project", name="xyz", )
# Out:
# (Project__xyz__45164a9c108a4bc4aad77298ab3f5380)

# %%
sdata.SUUID.from_name(class_name="Project", name="xyz", ns_name="!").sname
# Out:
# 'Project__xyz__af5b3de7387f56c1ad8685f5c43fd7f2'

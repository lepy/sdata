# %%
#setup notebook
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#%matplotlib notebook
#%autosave 0
import base64
import pandas as pd
import numpy as np
import uuid
import os
import sys
import logging
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.WARNING, datefmt='%I:%M:%S')

import sdata
from sdata import SUUID
from sdata.sclass.process import SpecificInput, SpecificOutput, ProcessData, ProcessNode, SpecificProcessNode

# %%
import sdata.base
s= SUUID(class_name="a", name="b")
j = sdata.base.to_json(s) 
j
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import sdata.base
#       2 s= SUUID(class_name="a", name="b")
# ----> 3 j = sdata.base.to_json(s)
#       4 j
#
# AttributeError: module 'sdata.base' has no attribute 'to_json'

# %%
s.to_dict()

# %%
sdata.base.from_json(j)

# %%
sdata.base.obj_to_spec(s)

# %%
input_a = SpecificInput(name="input", attributes=[{"name":"a", "value": 1.2},
                                                  {"name":"b", "value": 3}])
input_a.mdf
# Out:
#                                       name  \
# key
# _sdata_bfo_class          _sdata_bfo_class
# _sdata_class                  _sdata_class
# _sdata_name                    _sdata_name
# _sdata_parent_sname    _sdata_parent_sname
# _sdata_project_sname  _sdata_project_sname
# _sdata_sname                  _sdata_sname
# _sdata_suuid                  _sdata_suuid
# _sdata_version              _sdata_version
# a                                        a
# b                                        b
#
#                                                                   value unit  \
# key
# _sdata_bfo_class            sdata.sclass:GenericallyDependentContinuant    -
# _sdata_class                         sdata.sclass.process:SpecificInput    -
# _sdata_name                                                       input    -
# _sdata_parent_sname                                                        -
# _sdata_project_sname                                                       -
# _sdata_sname          SpecificInput@input@e4148fd84e9f4ef5bde1633edc...    -
# _sdata_suuid          ZTQxNDhmZDg0ZTlmNGVmNWJkZTE2MzNlZGM0Y2ZmMzdTcG...    -
# _sdata_version                                                   0.26.0    -
# a                                                                   1.2    -
# b                                                                     3  MPa
#
#                       dtype                          description label  \
# key
# _sdata_bfo_class        str                 sdata bfo class name
# _sdata_class            str                          sdata class
# _sdata_name             str              name of the data object
# _sdata_parent_sname     str                  sname of the parent
# _sdata_project_sname    str                 sname of the project
# _sdata_sname            str             sname of the data object
# _sdata_suuid            str  Super Universally Unique Identifier
# _sdata_version          str                sdata package version
# a                     float                           my a value   $a$
# b                       int                           my b value   $b$
#
#                       required
# key
# _sdata_bfo_class          True
# _sdata_class              True
# _sdata_name               True
# _sdata_parent_sname      False
# _sdata_project_sname     False
# _sdata_sname              True
# _sdata_suuid              True
# _sdata_version            True
# a                         True
# b                         True

# %%
type(input_a)
# Out:
# sdata.sclass.process.SpecificInput

# %%
s= SUUID(class_name="a", name="b")
type(s)
# Out:
# sdata.suuid.SUUID

# %%
input_a.default_attributes
# Out:
# [{'name': 'a',
#   'value': None,
#   'dtype': float,
#   'label': 'an a',
#   'required': True},
#  {'name': 'b', 'value': None, 'dtype': int, 'label': 'an b', 'required': True}]

# %%
input_a.mdf
# Out:
#                                       name  \
# key
# _sdata_class                  _sdata_class
# _sdata_name                    _sdata_name
# _sdata_parent_sname    _sdata_parent_sname
# _sdata_project_sname  _sdata_project_sname
# _sdata_sname                  _sdata_sname
# _sdata_suuid                  _sdata_suuid
# _sdata_version              _sdata_version
# a                                        a
# b                                        b
#
#                                                                   value unit  \
# key
# _sdata_class                                              SpecificInput    -
# _sdata_name                                                       input    -
# _sdata_parent_sname                                                        -
# _sdata_project_sname                                                       -
# _sdata_sname          SpecificInput@input@2ab239d60f024404b673ce587b...    -
# _sdata_suuid          MmFiMjM5ZDYwZjAyNDQwNGI2NzNjZTU4N2IyN2ViZmRTcG...    -
# _sdata_version                                                   0.26.0    -
# a                                                                   1.2    -
# b                                                                     3    -
#
#                       dtype                          description label  \
# key
# _sdata_class            str                          sdata class
# _sdata_name             str              name of the data object
# _sdata_parent_sname     str                  sname of the parent
# _sdata_project_sname    str                 sname of the project
# _sdata_sname            str             sname of the data object
# _sdata_suuid            str  Super Universally Unique Identifier
# _sdata_version          str                sdata package version
# a                     float                                       an a
# b                       int                                       an b
#
#                       required
# key
# _sdata_class              True
# _sdata_name               True
# _sdata_parent_sname      False
# _sdata_project_sname     False
# _sdata_sname              True
# _sdata_suuid              True
# _sdata_version            True
# a                         True
# b                         True

# %%
input_a.is_complete()
# Out:
# True

# %%
# Gültiger Knoten
node = SpecificProcessNode(
    name="MyNode",
    inputs={"input1": input_a}
)
try:
    node.validate_inputs()  # Erfolgreich
    outputs = node.run()  # Erzeugt Outputs
    print("Valid node ran successfully.")
except ValueError as e:
    print(f"Valid node error: {e}")
node
# Out:
# Valid node ran successfully.
# <SpecificProcessNode@mynode@f2e648818960483cbe3c6aedc69a093f>

# %%
node.outputs['output1'].udf
# Out:
#     name  value unit  dtype description label  required
# key
# c      c    4.2    -  float                       False

# %%
input_a = SpecificInput(name="input", attributes=[{"name": "a", "value": 1.2},
                                                  {"name": "b", "value": 3}])
# Gültiger Knoten
node = SpecificProcessNode(
    name="MyNode",
    inputs={"input1": SpecificInput(name="Input1", metadata={"data": "value"})}
)
try:
    node.validate_inputs()  # Erfolgreich
    outputs = node.run()  # Erzeugt Outputs
    print("Valid node ran successfully.")
except ValueError as e:
    print(f"Valid node error: {e}")
node
# Out:
# Valid node ran successfully.
# <SpecificProcessNode@mynode@cc66484e34e64e6bac3be8de3e2fd001>

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %autosave 0

import logging
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.WARNING, datefmt='%I:%M:%S')

import os
import sys
import numpy as np
import pandas as pd
import sdata
import uuid
import json
import PIL
print("sdata v{}".format(sdata.__version__))
# Out:
# Autosave disabled
# sdata v0.22.4

# %%
imagepath = "../tests/images/a.png"
img = PIL.Image.open(imagepath)
img.info
# Out:
# {'loop': 1, 'background': (255, 255, 255, 255)}

# %%
png = sdata.Image.from_filepath(imagepath, project="ImageProject", description="a png image")
png
# Out:
# (Image 'a.png':1c2003dfd5f053f3b16b8b088c009f34)

# %%
png.mdf
# Out:
#                           name  \
# key
# !sdata_class      !sdata_class
# !sdata_ctime      !sdata_ctime
# !sdata_mtime      !sdata_mtime
# !sdata_name        !sdata_name
# !sdata_parent    !sdata_parent
# !sdata_project  !sdata_project
# !sdata_suuid      !sdata_suuid
# !sdata_uuid        !sdata_uuid
# !sdata_version  !sdata_version
#
#                                                             value dtype unit  \
# key
# !sdata_class                                                Image   str    -
# !sdata_ctime                     2024-03-05T15:47:19.243806+00:00   str    -
# !sdata_mtime                     2024-03-05T15:47:19.244149+00:00   str    -
# !sdata_name                                                 a.png   str    -
# !sdata_parent                                                       str    -
# !sdata_project                                       ImageProject   str    -
# !sdata_suuid    MWMyMDAzZGZkNWYwNTNmM2IxNmI4YjA4OGMwMDlmMzRJbW...   str    -
# !sdata_uuid                      1c2003dfd5f053f3b16b8b088c009f34   str    -
# !sdata_version                                             0.22.4   str    -
#
#                                         description label  required
# key
# !sdata_class                            sdata class           False
# !sdata_ctime                          creation date           False
# !sdata_mtime                      modification date           False
# !sdata_name                 name of the data object           False
# !sdata_parent       uuid of the parent sdata object           False
# !sdata_project                                                False
# !sdata_suuid    Super Universally Unique Identifier           False
# !sdata_uuid           Universally Unique Identifier           False
# !sdata_version                sdata package version           False

# %%
png.load()
png.img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1024x1024>

# %%
#png.save("../tests/images/sdata.png")

# %%
imagepath = "../tests/images/sdata.png"
png = sdata.Image.from_filepath(imagepath, project="ImageProject", description="a png image")
png
# Out:
# (Image 'sdata.png':897ba57c703e51caa3db81443f348711)

# %%
png.mdf
# Out:
#                           name  \
# key
# !sdata_class      !sdata_class
# !sdata_ctime      !sdata_ctime
# !sdata_mtime      !sdata_mtime
# !sdata_name        !sdata_name
# !sdata_parent    !sdata_parent
# !sdata_project  !sdata_project
# !sdata_suuid      !sdata_suuid
# !sdata_uuid        !sdata_uuid
# !sdata_version  !sdata_version
#
#                                                             value dtype unit  \
# key
# !sdata_class                                                Image   str    -
# !sdata_ctime                     2024-03-05T15:47:19.630062+00:00   str    -
# !sdata_mtime                     2024-03-05T15:47:19.630136+00:00   str    -
# !sdata_name                                             sdata.png   str    -
# !sdata_parent                                                       str    -
# !sdata_project                                       ImageProject   str    -
# !sdata_suuid    ODk3YmE1N2M3MDNlNTFjYWEzZGI4MTQ0M2YzNDg3MTFJbW...   str    -
# !sdata_uuid                      897ba57c703e51caa3db81443f348711   str    -
# !sdata_version                                             0.22.4   str    -
#
#                                         description label  required
# key
# !sdata_class                            sdata class           False
# !sdata_ctime                          creation date           False
# !sdata_mtime                      modification date           False
# !sdata_name                 name of the data object           False
# !sdata_parent       uuid of the parent sdata object           False
# !sdata_project                                                False
# !sdata_suuid    Super Universally Unique Identifier           False
# !sdata_uuid           Universally Unique Identifier           False
# !sdata_version                sdata package version           False

# %%
imagepath = "../tests/images/a.jpg"
jpg = sdata.Image.from_filepath(imagepath, project="ImageProject", description="a jpg image")
jpg
# Out:
# (Image 'a.jpg':13c13d9b1aee5662a6952ec1712dd2fe)

# %%
jpg.mdf
# Out:
#                           name  \
# key
# !sdata_class      !sdata_class
# !sdata_ctime      !sdata_ctime
# !sdata_mtime      !sdata_mtime
# !sdata_name        !sdata_name
# !sdata_parent    !sdata_parent
# !sdata_project  !sdata_project
# !sdata_suuid      !sdata_suuid
# !sdata_uuid        !sdata_uuid
# !sdata_version  !sdata_version
#
#                                                             value dtype unit  \
# key
# !sdata_class                                                Image   str    -
# !sdata_ctime                     2024-03-05T15:47:19.682836+00:00   str    -
# !sdata_mtime                     2024-03-05T15:47:19.682909+00:00   str    -
# !sdata_name                                                 a.jpg   str    -
# !sdata_parent                                                       str    -
# !sdata_project                                       ImageProject   str    -
# !sdata_suuid    MTNjMTNkOWIxYWVlNTY2MmE2OTUyZWMxNzEyZGQyZmVJbW...   str    -
# !sdata_uuid                      13c13d9b1aee5662a6952ec1712dd2fe   str    -
# !sdata_version                                             0.22.4   str    -
#
#                                         description label  required
# key
# !sdata_class                            sdata class           False
# !sdata_ctime                          creation date           False
# !sdata_mtime                      modification date           False
# !sdata_name                 name of the data object           False
# !sdata_parent       uuid of the parent sdata object           False
# !sdata_project                                                False
# !sdata_suuid    Super Universally Unique Identifier           False
# !sdata_uuid           Universally Unique Identifier           False
# !sdata_version                sdata package version           False

# %%
jpg.save("../tests/images/sdata.jpg")

# %%
imagepath = "../tests/images/sdata.jpg"
jpg = sdata.Image.from_filepath(imagepath, project="ImageProject", description="a jpg image")
jpg
# Out:
# (Image 'sdata.jpg':9f44d9da200e56298c6f3a18896be52c)

# %%
jpg.mdf
# Out:
#                           name  \
# key
# !sdata_class      !sdata_class
# !sdata_ctime      !sdata_ctime
# !sdata_mtime      !sdata_mtime
# !sdata_name        !sdata_name
# !sdata_parent    !sdata_parent
# !sdata_project  !sdata_project
# !sdata_suuid      !sdata_suuid
# !sdata_uuid        !sdata_uuid
# !sdata_version  !sdata_version
#
#                                                             value dtype unit  \
# key
# !sdata_class                                                Image   str    -
# !sdata_ctime                     2024-03-05T15:47:20.015324+00:00   str    -
# !sdata_mtime                     2024-03-05T15:47:20.015413+00:00   str    -
# !sdata_name                                             sdata.jpg   str    -
# !sdata_parent                                                       str    -
# !sdata_project                                       ImageProject   str    -
# !sdata_suuid    OWY0NGQ5ZGEyMDBlNTYyOThjNmYzYTE4ODk2YmU1MmNJbW...   str    -
# !sdata_uuid                      9f44d9da200e56298c6f3a18896be52c   str    -
# !sdata_version                                             0.22.4   str    -
#
#                                         description label  required
# key
# !sdata_class                            sdata class           False
# !sdata_ctime                          creation date           False
# !sdata_mtime                      modification date           False
# !sdata_name                 name of the data object           False
# !sdata_parent       uuid of the parent sdata object           False
# !sdata_project                                                False
# !sdata_suuid    Super Universally Unique Identifier           False
# !sdata_uuid           Universally Unique Identifier           False
# !sdata_version                sdata package version           False

# %%
imagepath = "../tests/images/a.webp"
webp = sdata.Image.from_filepath(imagepath, project="ImageProject", description="a webp image")
#webp.load()
webp
# Out:
# (Image 'a.webp':1c2003dfd5f053f3b16b8b088c009f34)

# %%
webp.save("/tmp/webp.jpg")

# %%
imagepath = "/tmp/webp.jpg"
jpg = sdata.Image.from_filepath(imagepath, project="ImageProject", description="a jpg image")
jpg.mdf
# Out:
#                           name  \
# key
# !sdata_class      !sdata_class
# !sdata_ctime      !sdata_ctime
# !sdata_mtime      !sdata_mtime
# !sdata_name        !sdata_name
# !sdata_parent    !sdata_parent
# !sdata_project  !sdata_project
# !sdata_suuid      !sdata_suuid
# !sdata_uuid        !sdata_uuid
# !sdata_version  !sdata_version
#
#                                                             value dtype unit  \
# key
# !sdata_class                                                Image   str    -
# !sdata_ctime                     2024-03-05T15:47:20.371948+00:00   str    -
# !sdata_mtime                     2024-03-05T15:47:20.372014+00:00   str    -
# !sdata_name                                              webp.jpg   str    -
# !sdata_parent                                                       str    -
# !sdata_project                                       ImageProject   str    -
# !sdata_suuid    OTFmNTc3OGI3NWZmNTQzYjliZTQzZTYxNmUxNTJjZDNJbW...   str    -
# !sdata_uuid                      91f5778b75ff543b9be43e616e152cd3   str    -
# !sdata_version                                             0.22.4   str    -
#
#                                         description label  required
# key
# !sdata_class                            sdata class           False
# !sdata_ctime                          creation date           False
# !sdata_mtime                      modification date           False
# !sdata_name                 name of the data object           False
# !sdata_parent       uuid of the parent sdata object           False
# !sdata_project                                                False
# !sdata_suuid    Super Universally Unique Identifier           False
# !sdata_uuid           Universally Unique Identifier           False
# !sdata_version                sdata package version           False

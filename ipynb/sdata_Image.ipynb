# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %autosave 0

import logging
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.WARNING, datefmt='%I:%M:%S')

import os
import sys
import numpy as np
import pandas as pd
import sdata
import uuid
import json
from sdata.sclass.image import Image
import PIL
print("sdata v{}".format(sdata.__version__))
# Out:
# Autosave disabled
# sdata v0.26.0

# %%
imagepath = "../tests/images/a.png"
img = PIL.Image.open(imagepath)
img.info
# Out:
# {'loop': 1, 'background': (255, 255, 255, 255)}

# %%
png = Image.from_file(imagepath, project="ImageProject", description="a png image")
png
# Out:
# 10:10:43 WARNING:project must be of type Base, got (<class 'object'>,)
# <Image@a_png@b980e71fc9ac446180531f563ee075ab>

# %%
png.name
# Out:
# 'a.png'

# %%
png.md.add_attribute("s")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 png.md.add_attribute("s")
#
# File ~/projects/sdata/sdata/metadata.py:312, in Metadata.add_attribute(self, attr, **kwargs)
#     310 prefix: str = kwargs.get("prefix", "")
#     311 if not isinstance(attr, Attribute):
# --> 312     raise TypeError(f"attr must be an instance of Attribute, got {type(attr).__name__}")
#     313 self._attributes[prefix + attr.name] = attr
#
# TypeError: attr must be an instance of Attribute, got str

# %%
png.md.add(name="a", value=3., unit="mm")

# %%
png.md.add(name="url", value="b.png")

# %%
png.mdf
# Out:
#                                         name  \
# key
# _sdata_class                    _sdata_class
# _sdata_name                      _sdata_name
# _sdata_parent_sname      _sdata_parent_sname
# _sdata_sname                    _sdata_sname
# _sdata_suuid                    _sdata_suuid
# _sdata_topology_class  _sdata_topology_class
# _sdata_version                _sdata_version
# a                                          a
# url                                      url
#
#                                                                    value unit  \
# key
# _sdata_class                                    sdata.sclass.image:Image    -
# _sdata_name                                                        a.png    -
# _sdata_parent_sname                                                         -
# _sdata_sname                Image@a_png@0dd9f28caa1c4c95851365b2c4471813    -
# _sdata_suuid           MGRkOWYyOGNhYTFjNGM5NTg1MTM2NWIyYzQ0NzE4MTNJbW...    -
# ...

# %%
png.load()
png.img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1024x1024>

# %%
#png.save("../tests/images/sdata.png")

# %%
imagepath = "../tests/images/sdata.png"
img = PIL.Image.open(imagepath)
img.info
# Out:
# {'sdata': '"{\\"_sdata_class\\": {\\"name\\": \\"_sdata_class\\", \\"value\\": \\"sdata.sclass.image:Image\\", \\"unit\\": \\"-\\", \\"dtype\\": \\"str\\", \\"description\\": \\"sdata class\\", \\"label\\": \\"\\", \\"required\\": true}, \\"_sdata_name\\": {\\"name\\": \\"_sdata_name\\", \\"value\\": \\"a.png\\", \\"unit\\": \\"-\\", \\"dtype\\": \\"str\\", \\"description\\": \\"name of the data object\\", \\"label\\": \\"\\", \\"required\\": true}, \\"_sdata_parent_sname\\": {\\"name\\": \\"_sdata_parent_sname\\", \\"value\\": \\"\\", \\"unit\\": \\"-\\", \\"dtype\\": \\"str\\", \\"description\\": \\"sname of the parent\\", \\"label\\": \\"\\", \\"required\\": false}, \\"_sdata_sname\\": {\\"name\\": \\"_sdata_sname\\", \\"value\\": \\"Image@a_png@6013c7242a73479a98a18a51fd9d66f7\\", \\"unit\\": \\"-\\", \\"dtype\\": \\"str\\", \\"description\\": \\"sname of the data object\\", \\"label\\": \\"\\", \\"required\\": true}, \\"_sdata_suuid\\": {\\"name\\": \\"_sdata_suuid\\", \\"value\
# ...

# %%
imagepath = "../tests/images/sdata.png"
png = Image.from_file(imagepath, project="ImageProject", description="a png image")
png, png.suuid
# Out:
# 04:36:03 WARNING:project must be of type Base, got (<class 'object'>,)
# (<Image@sdata_png@efa6e8070be54b33b2a0e86323d51f48>,
#  (Image@sdata_png@efa6e8070be54b33b2a0e86323d51f48))

# %%
png.metadata.get(png.SDATA_SUUID), png.SDATA_SUUID
# Out:
# ((Attr'_sdata_suuid':ZWZhNmU4MDcwYmU1NGIzM2IyYTBlODYzMjNkNTFmNDhJbWFnZUBzZGF0YV9wbmc=(str)),
#  '_sdata_suuid')

# %%
imagepath = "../tests/images/sdata.png"
png = Image.from_png(imagepath, project="ImageProject", description="a png image")
png
# Out:
# 04:36:03 WARNING:project must be of type Base, got (<class 'object'>,)
# <Image@sdata_png@9400dbd94ebb4d529f4c9e8dc9d71c91>

# %%
png.mdf
# Out:
#                                         name  \
# key
# _sdata_class                    _sdata_class
# _sdata_name                      _sdata_name
# _sdata_parent_sname      _sdata_parent_sname
# _sdata_sname                    _sdata_sname
# _sdata_suuid                    _sdata_suuid
# _sdata_topology_class  _sdata_topology_class
# _sdata_version                _sdata_version
#
#                                                                    value unit  \
# key
# _sdata_class                                    sdata.sclass.image:Image    -
# _sdata_name                                                    sdata.png    -
# _sdata_parent_sname                                                         -
# _sdata_sname            Image@sdata_png@9400dbd94ebb4d529f4c9e8dc9d71c91    -
# _sdata_suuid           OTQwMGRiZDk0ZWJiNGQ1MjlmNGM5ZThkYzlkNzFjOTFJbW...    -
# _sdata_topology_class                 sdata.sclass:IndependentContinuant    -
# ...

# %%
imagepath = "../tests/images/a.jpg"
jpg = sdata.Image.from_file(imagepath, project="ImageProject", description="a jpg image")
jpg, jpg.suuid
# Out:
# 04:36:03 WARNING:project must be of type Base, got (<class 'object'>,)
# (<Image@a_jpg@479e72a98aaa4dfbbec1819d79333c52>,
#  (Image@a_jpg@479e72a98aaa4dfbbec1819d79333c52))

# %%
imagepath = "../tests/images/a.jpg"
jpg = sdata.Image.from_jpg(imagepath, project="ImageProject", description="a jpg image")
jpg, jpg.suuid
# Out:
# 04:36:03 WARNING:project must be of type Base, got (<class 'object'>,)
# (<Image@a_jpg@455e7f3b552c4719a539e55319e3164d>,
#  (Image@a_jpg@455e7f3b552c4719a539e55319e3164d))

# %%
jpg.mdf
# Out:
#                                         name  \
# key
# _sdata_class                    _sdata_class
# _sdata_name                      _sdata_name
# _sdata_parent_sname      _sdata_parent_sname
# _sdata_sname                    _sdata_sname
# _sdata_suuid                    _sdata_suuid
# _sdata_topology_class  _sdata_topology_class
# _sdata_version                _sdata_version
#
#                                                                    value unit  \
# key
# _sdata_class                                    sdata.sclass.image:Image    -
# _sdata_name                                                        a.jpg    -
# _sdata_parent_sname                                                         -
# _sdata_sname                Image@a_jpg@455e7f3b552c4719a539e55319e3164d    -
# _sdata_suuid           NDU1ZTdmM2I1NTJjNDcxOWE1MzllNTUzMTllMzE2NGRJbW...    -
# _sdata_topology_class                 sdata.sclass:IndependentContinuant    -
# ...

# %%
#jpg.save("../tests/images/sdata.jpg")

# %%
imagepath = "../tests/images/sdata.jpg"
jpg = Image.from_file(imagepath, project="ImageProject", description="a jpg image")
jpg, jpg.suuid
# Out:
# 04:36:03 WARNING:project must be of type Base, got (<class 'object'>,)
# (<Image@sdata_jpg@c8530d8e995e4317a322bd9f836ed769>,
#  (Image@sdata_jpg@c8530d8e995e4317a322bd9f836ed769))

# %%
jpg.mdf
# Out:
#                                         name  \
# key
# _sdata_class                    _sdata_class
# _sdata_name                      _sdata_name
# _sdata_parent_sname      _sdata_parent_sname
# _sdata_sname                    _sdata_sname
# _sdata_suuid                    _sdata_suuid
# _sdata_topology_class  _sdata_topology_class
# _sdata_version                _sdata_version
#
#                                                                    value unit  \
# key
# _sdata_class                                    sdata.sclass.image:Image    -
# _sdata_name                                                    sdata.jpg    -
# _sdata_parent_sname                                                         -
# _sdata_sname            Image@sdata_jpg@c8530d8e995e4317a322bd9f836ed769    -
# _sdata_suuid           Yzg1MzBkOGU5OTVlNDMxN2EzMjJiZDlmODM2ZWQ3NjlJbW...    -
# _sdata_topology_class                 sdata.sclass:IndependentContinuant    -
# ...

# %%
imagepath = "../tests/images/sdata.jpg"
jpg = sdata.Image.from_jpg(imagepath, project="ImageProject", description="a jpg image")
jpg, jpg.suuid
# Out:
# 04:36:03 WARNING:project must be of type Base, got (<class 'object'>,)
# (<Image@sdata_jpg@2cc06755d5694c7096b2550f4bae4562>,
#  (Image@sdata_jpg@2cc06755d5694c7096b2550f4bae4562))

# %%
imagepath = "../tests/images/a.jpg"
jpg._get_jpg_metadata(imagepath)

# %%
jpg.mdf
# Out:
#                                         name  \
# key
# _sdata_class                    _sdata_class
# _sdata_name                      _sdata_name
# _sdata_parent_sname      _sdata_parent_sname
# _sdata_sname                    _sdata_sname
# _sdata_suuid                    _sdata_suuid
# _sdata_topology_class  _sdata_topology_class
# _sdata_version                _sdata_version
#
#                                                                    value unit  \
# key
# _sdata_class                                    sdata.sclass.image:Image    -
# _sdata_name                                                    sdata.jpg    -
# _sdata_parent_sname                                                         -
# _sdata_sname            Image@sdata_jpg@2cc06755d5694c7096b2550f4bae4562    -
# _sdata_suuid           MmNjMDY3NTVkNTY5NGM3MDk2YjI1NTBmNGJhZTQ1NjJJbW...    -
# _sdata_topology_class                 sdata.sclass:IndependentContinuant    -
# ...

# %%
imagepath = "../tests/images/a.webp"
webp = sdata.Image.from_file(imagepath, project="ImageProject", description="a webp image")
#webp.load()
webp, webp.suuid
# Out:
# 04:36:03 WARNING:project must be of type Base, got (<class 'object'>,)
# (<Image@a_webp@accc9ec3fea1473492016c51b4c0b285>,
#  (Image@a_webp@accc9ec3fea1473492016c51b4c0b285))

# %%
webp.save("/tmp/webp.jpg")

# %%
imagepath = "/tmp/webp.jpg"
webp = sdata.Image.from_file(imagepath, project="ImageProject", description="a webp image")
webp.mdf
# Out:
# 04:36:03 WARNING:project must be of type Base, got (<class 'object'>,)
#                                         name  \
# key
# _sdata_class                    _sdata_class
# _sdata_name                      _sdata_name
# _sdata_parent_sname      _sdata_parent_sname
# _sdata_sname                    _sdata_sname
# _sdata_suuid                    _sdata_suuid
# _sdata_topology_class  _sdata_topology_class
# _sdata_version                _sdata_version
#
#                                                                    value unit  \
# key
# _sdata_class                                    sdata.sclass.image:Image    -
# _sdata_name                                                     webp.jpg    -
# _sdata_parent_sname                                                         -
# _sdata_sname             Image@webp_jpg@bfe0ce1805f54dfabdc8f0ec58d8db06    -
# _sdata_suuid           YmZlMGNlMTgwNWY1NGRmYWJkYzhmMGVjNThkOGRiMDZJbW...    -
# ...

# %%
imagepath = "../tests/images/sdata.png"
sdata.Image._get_png_metadata(imagepath)
# Out:
# '{"_sdata_class": {"name": "_sdata_class", "value": "sdata.sclass.image:Image", "unit": "-", "dtype": "str", "description": "sdata class", "label": "", "required": true}, "_sdata_name": {"name": "_sdata_name", "value": "a.png", "unit": "-", "dtype": "str", "description": "name of the data object", "label": "", "required": true}, "_sdata_parent_sname": {"name": "_sdata_parent_sname", "value": "", "unit": "-", "dtype": "str", "description": "sname of the parent", "label": "", "required": false}, "_sdata_sname": {"name": "_sdata_sname", "value": "Image@a_png@6013c7242a73479a98a18a51fd9d66f7", "unit": "-", "dtype": "str", "description": "sname of the data object", "label": "", "required": true}, "_sdata_suuid": {"name": "_sdata_suuid", "value": "NjAxM2M3MjQyYTczNDc5YTk4YTE4YTUxZmQ5ZDY2ZjdJbWFnZUBhX3BuZw==", "unit": "-", "dtype": "str", "description": "Super Universally Unique Identifier", "label": "", "required": true}, "_sdata_topology_class": {"name": "_sdata_topology_class", "value": 
# ...

# %%
a = sdata.Data(name="a", project="aa")
print(a, a.suuid)
a.mdf
# Out:
# (Data 'a':5405db6b65984ae89f4ebd84eaac2c21) NTQwNWRiNmI2NTk4NGFlODlmNGViZDg0ZWFhYzJjMjFEYXRhQGE=
#                           name  \
# key
# !sdata_class      !sdata_class
# !sdata_ctime      !sdata_ctime
# !sdata_mtime      !sdata_mtime
# !sdata_name        !sdata_name
# !sdata_parent    !sdata_parent
# !sdata_project  !sdata_project
# !sdata_sname      !sdata_sname
# !sdata_suuid      !sdata_suuid
# !sdata_url          !sdata_url
# !sdata_uuid        !sdata_uuid
# !sdata_version  !sdata_version
#
#                                                             value unit dtype  \
# key
# !sdata_class                                                 Data    -   str
# !sdata_ctime                     2025-09-15T16:36:03.408526+00:00    -   str
# !sdata_mtime                     2025-09-15T16:36:03.408586+00:00    -   str
# !sdata_name                                                     a    -   str
# !sdata_parent                                                        -   str
# ...

# %%
b = a.rename("c", random=False)
print(b, b.suuid)
b.mdf
# Out:
# (Data 'c':0c9bfbfc373c50e382c5cd395ac2cd1e) MGM5YmZiZmMzNzNjNTBlMzgyYzVjZDM5NWFjMmNkMWVEYXRhQGM=
#                           name  \
# key
# !sdata_class      !sdata_class
# !sdata_ctime      !sdata_ctime
# !sdata_mtime      !sdata_mtime
# !sdata_name        !sdata_name
# !sdata_parent    !sdata_parent
# !sdata_project  !sdata_project
# !sdata_sname      !sdata_sname
# !sdata_suuid      !sdata_suuid
# !sdata_url          !sdata_url
# !sdata_uuid        !sdata_uuid
# !sdata_version  !sdata_version
#
#                                                             value unit dtype  \
# key
# !sdata_class                                                 Data    -   str
# !sdata_ctime                     2025-09-15T16:36:03.408526+00:00    -   str
# !sdata_mtime                     2025-09-15T16:36:03.408586+00:00    -   str
# !sdata_name                                                     c    -   str
# !sdata_parent                                                        -   str
# ...

# %%
imagepath = "../tests/images/sdata.png"
png = Image.from_png(imagepath, project="ImageProject", description="a png image")
print(png, png.suuid, png.project)
png.mdf
# Out:
# 04:36:03 WARNING:project must be of type Base, got (<class 'object'>,)
# <Image@sdata_png@bb0abe237bdc42a18d5eb7c89283f196> (Image@sdata_png@bb0abe237bdc42a18d5eb7c89283f196) None
#                                         name  \
# key
# _sdata_class                    _sdata_class
# _sdata_name                      _sdata_name
# _sdata_parent_sname      _sdata_parent_sname
# _sdata_sname                    _sdata_sname
# _sdata_suuid                    _sdata_suuid
# _sdata_topology_class  _sdata_topology_class
# _sdata_version                _sdata_version
#
#                                                                    value unit  \
# key
# _sdata_class                                    sdata.sclass.image:Image    -
# _sdata_name                                                    sdata.png    -
# _sdata_parent_sname                                                         -
# _sdata_sname            Image@sdata_png@bb0abe237bdc42a18d5eb7c89283f196    -
# ...

# %%
png.mdf
# Out:
#                                         name  \
# key
# _sdata_class                    _sdata_class
# _sdata_name                      _sdata_name
# _sdata_parent_sname      _sdata_parent_sname
# _sdata_sname                    _sdata_sname
# _sdata_suuid                    _sdata_suuid
# _sdata_topology_class  _sdata_topology_class
# _sdata_version                _sdata_version
#
#                                                                    value unit  \
# key
# _sdata_class                                    sdata.sclass.image:Image    -
# _sdata_name                                                    sdata.png    -
# _sdata_parent_sname                                                         -
# _sdata_sname            Image@sdata_png@bb0abe237bdc42a18d5eb7c89283f196    -
# _sdata_suuid           YmIwYWJlMjM3YmRjNDJhMThkNWViN2M4OTI4M2YxOTZJbW...    -
# _sdata_topology_class                 sdata.sclass:IndependentContinuant    -
# ...

# %%
#png.rename("another.png", random=False)
#print(png, png.suuid, png.project)
#png.mdf

# %%
#png.rename("another.png")
#print(png, png.suuid, png.project)
#png.mdf

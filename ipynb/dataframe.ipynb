# %%
#setup notebook
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#%matplotlib notebook
#%autosave 0
import base64
import pandas as pd
import numpy as np
import uuid
import os
import sys
import logging
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.WARNING, datefmt='%I:%M:%S')

import sdata
from sdata import SUUID
from sdata.base import Base, sdata_factory
from sdata.sclass.dataframe import DataFrame

# %%
import pandas as pd
df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': ['apple', 'banana', 'cherry']
})
df.to_parquet('/tmp/df1.pq', index=False)

# %%
# Erstelle einen Pandas DataFrame
import pandas as pd

df = pd.DataFrame({
    'weight': [10, 20, 30],
    'height': [1.5, 1.6, 1.7]
})

# Erstelle eine SDataFrame-Instanz mit Metadaten
column_meta = {
    'weight': {'label': 'Gewicht', 'unit': 'kg'},
    'height': {'label': 'Höhe', 'unit': 'm'}
}
sdf = DataFrame(df=df, column_metadata=column_meta, name="MeinDataFrame", description="Beispieldaten")
sdf

# %%
df.to_parquet("/tmp/df.pq")

# %%
sdf.column_metadata
# Out:
# {'weight': {'label': 'Gewicht', 'unit': 'kg'},
#  'height': {'label': 'Höhe', 'unit': 'm'}}

# %%
sdf.df
# Out:
#    weight  height
# 0      10     1.5
# 1      20     1.6
# 2      30     1.7

# %%
sdf.to_dict()
# Out:
# {'metadata': {'_sdata_bfo_class': {'name': '_sdata_bfo_class',
#    'value': 'sdata.sclass:IndependentContinuant',
#    'unit': '-',
#    'dtype': 'str',
#    'description': 'sdata bfo class name',
#    'label': '',
#    'required': True},
#   '_sdata_class': {'name': '_sdata_class',
#    'value': 'sdata.sclass.dataframe:DataFrame',
#    'unit': '-',
#    'dtype': 'str',
#    'description': 'sdata class',
#    'label': '',
#    'required': True},
#   '_sdata_name': {'name': '_sdata_name',
#    'value': 'MeinDataFrame',
#    'unit': '-',
#    'dtype': 'str',
#    'description': 'name of the data object',
#    'label': '',
#    'required': True},
#   '_sdata_parent_sname': {'name': '_sdata_parent_sname',
#    'value': '',
#    'unit': '-',
#    'dtype': 'str',
#    'description': 'sname of the parent',
#    'label': '',
#    'required': False},
#   '_sdata_project_sname': {'name': '_sdata_project_sname',
#    'value': '',
#    'unit': '-',
#    'dtype': 'str',
# ...

# %%
sdf.df
# Out:
#    weight  height
# 0      10     1.5
# 1      20     1.6
# 2      30     1.7

# %%
d2 = DataFrame.from_dict(sdf.to_dict())
d2.df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 d2 = DataFrame.from_dict(sdf.to_dict())
# ----> 2 d2.df
#
# AttributeError: 'DataFrame' object has no attribute 'df'

# %%
serialized = sdf.to_dict()
restored_sdf = DataFrame.from_dict(serialized)
print(restored_sdf.df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 serialized = sdf.to_dict()
#       2 restored_sdf = DataFrame.from_dict(serialized)
# ----> 3 print(restored_sdf.df)
#
# AttributeError: 'DataFrame' object has no attribute 'df'

# %%
type(restored_sdf)

# %%
DataFrame().df

# %%
sdata_factory("A", DataFrame).df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sdata_factory("A", DataFrame).df
#
# File ~/projects/sdata/sdata/dataframe.py:64, in DataFrame.df(self)
#      61 if 'df_cached' in self.data:
#      62     return self.data['df_cached']
# ---> 64 content_bytes = self.content_bytes  # Lazy load from Blob
#      65 bytes_io = io.BytesIO(content_bytes)
#      66 loaded_df = pd.read_parquet(bytes_io, engine='pyarrow')
#
# File ~/projects/sdata/sdata/blob.py:119, in Blob.content_bytes(self)
#     117 val = content.get('value')
#     118 if val is None:
# --> 119     raise ValueError("No value set in content.")
#     121 if ctype == 'bytes':
#     122     loaded_bytes = base64.b64decode(val)
#
# ValueError: No value set in content.

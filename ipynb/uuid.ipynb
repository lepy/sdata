# %%
import uuid
import base64

# %%
i = uuid.uuid4()
i
# Out:
# UUID('6bd1524e-8099-48b9-86b2-7592a7dc36d1')

# %%
i.hex
# Out:
# '6bd1524e809948b986b27592a7dc36d1'

# %%
i.int
# Out:
# 143314254969603343264936901884740646609

# %%
f"{i}"
# Out:
# '6bd1524e-8099-48b9-86b2-7592a7dc36d1'

# %%
b = base64.encodestring(i.hex.encode("utf8"))
b
# Out:
# /home/ingolf.lepenies/anaconda3/envs/sfem3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: encodestring() is a deprecated alias since 3.1, use encodebytes()
#   """Entry point for launching an IPython kernel.
# b'NWQ5YWFhYTJmMGZiNDY1NWE3MzJlMmQwYjg5YWRkY2M=\n'

# %%
len(i.hex)
# Out:
# 32

# %%
uuid.UUID(i.hex)
# Out:
# UUID('5d9aaaa2-f0fb-4655-a732-e2d0b89addcc')

# %%
k = i.hex + "-asciiname"
k
# Out:
# '5d9aaaa2f0fb4655a732e2d0b89addcc-asciiname'

# %%
uuid.UUID()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-cd887c4b5f6b> in <module>
# ----> 1 uuid.UUID(i.hex+"123")
#
# ~/anaconda3/envs/sfem3/lib/python3.7/uuid.py in __init__(self, hex, bytes, bytes_le, fields, int, version, is_safe)
#     158             hex = hex.strip('{}').replace('-', '')
#     159             if len(hex) != 32:
# --> 160                 raise ValueError('badly formed hexadecimal UUID string')
#     161             int = int_(hex, 16)
#     162         if bytes_le is not None:
#
# ValueError: badly formed hexadecimal UUID string

# %%
uuid.uuid5(uuid.NAMESPACE_DNS, 'python.org')
# Out:
# UUID('886313e1-3b8a-5372-9b90-0c9aee199e5d')

# %%
j = uuid.uuid5(uuid.NAMESPACE_OID, 'python.org')
j
# Out:
# UUID('cd5d0bff-2444-5d26-ab53-4f7db1cb733d')

# %%
j.node
# Out:
# 87401272406845

# %%
i.fields
# Out:
# (1570417314, 61691, 18005, 167, 50, 249386078232012)
